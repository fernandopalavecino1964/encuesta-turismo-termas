# %%
import pandas as pd

df = pd.read_csv('/content/df_2.csv')
display(df.head())
# Out:
#                 fecha alojamiento       HPAs      HLimp      HWifi    HGastro  \
# 0   21/7/2025 8:56:40    Hotel 2*  Muy Bueno      Bueno  Muy Bueno      Bueno
# 1   21/7/2025 9:02:14     Cabañas  Excelente  Muy Bueno  Excelente  Excelente
# 2  21/7/2025 18:09:53    Hotel 3*  Muy Bueno  Muy Bueno      Bueno      Bueno
# 3  21/7/2025 18:17:08    Hotel 3*  Muy Bueno  Muy Bueno  Muy Bueno  Muy Bueno
# 4  21/7/2025 19:11:54    Hotel 3*  Muy Bueno  Excelente  Muy Bueno  Excelente
#
#      HEntret HSeguridad       HPyS         H$
# 0  Muy Bueno      Bueno  Muy Bueno  Muy Bueno
# 1  Muy Bueno  Muy Bueno  Excelente  Excelente
# 2  Muy Bueno  Excelente  Excelente  Excelente
# 3  Muy Bueno  Muy Bueno      Bueno  Muy Bueno
# 4  Muy Bueno  Excelente  Excelente  Muy Bueno

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fecha        27 non-null     object
#  1   alojamiento  27 non-null     object
#  2   HPAs         27 non-null     object
#  3   HLimp        27 non-null     object
#  4   HWifi        27 non-null     object
#  5   HGastro      27 non-null     object
#  6   HEntret      27 non-null     object
#  7   HSeguridad   27 non-null     object
#  8   HPyS         27 non-null     object
#  9   H$           27 non-null     object
# dtypes: object(10)
# memory usage: 2.2+ KB
# None

# %%
for col in df.columns:
    if col != 'fecha': # Assuming 'fecha' is the date column
        print(f"\nDistribución de la columna '{col}':")
        print(df[col].value_counts(normalize=True))
# Out:
# Distribución de la columna 'alojamiento':
# alojamiento
# Hotel 2*       0.444444
# Hotel 3*       0.259259
# Hotel 4*       0.111111
# Cabañas        0.074074
# Apart Hotel    0.074074
# Hotel 1*       0.037037
# Name: proportion, dtype: float64
#
# Distribución de la columna 'HPAs':
# HPAs
# Muy Bueno    0.518519
# Excelente    0.333333
# Bueno        0.148148
# Name: proportion, dtype: float64
#
# Distribución de la columna 'HLimp':
# HLimp
# Muy Bueno    0.444444
# Excelente    0.370370
# Bueno        0.185185
# Name: proportion, dtype: float64
#
# Distribución de la columna 'HWifi':
# HWifi
# Muy Bueno    0.444444
# Excelente    0.370370
# Bueno        0.111111
# Regular      0.074074
# Name: proportion, dtype: float64
#
# Distribución de la columna 'HGastro':
# HGastro
# Excelente    0.407407
# Muy Bueno    0.407407
# Bueno        0.185185
# Name: proportion, dtype: float64
#
# Distribución de la columna 'HEntret':
# HEntret
# Muy Bueno    0.481481
# Bueno        0.296296
# Excelente    0.222222
# Name: proportion, dtype: float64
#
# Distribución de la columna 'HSeguridad':
# HSeguridad
# Muy Bueno    0.518519
# Excelente    0.333333
# Bueno        0.148148
# Name: proportion, dtype: float64
#
# Distribución de la columna 'HPyS':
# HPyS
# Excelente    0.555556
# Muy Bueno    0.370370
# Bueno        0.074074
# Name: proportion, dtype: float64
#
# Distribución de la columna 'H$':
# H$
# Excelente    0.444444
# Muy Bueno    0.407407
# Bueno        0.148148
# Name: proportion, dtype: float64

# %% [markdown]
# Con la información de los tipos de datos y las distribuciones de las columnas categóricas, ahora puedo generar el DataFrame sintético. La columna `fecha` parece ser un objeto (string) que contiene fecha y hora. Para replicarla, primero la convertiré a tipo `datetime` para obtener el rango y luego generaré fechas aleatorias dentro de ese rango, manteniendo el formato original.

# %%
import numpy as np

# Convertir 'fecha' a datetime para obtener rango
df['fecha_dt'] = pd.to_datetime(df['fecha'], format='%d/%m/%Y %H:%M:%S')

min_date = df['fecha_dt'].min()
max_date = df['fecha_dt'].max()

# Número de registros para el DataFrame sintético
num_synthetic_records = 1000

synthetic_data = {}

# Generar la columna 'fecha' sintética
start_timestamp = min_date.timestamp()
end_timestamp = max_date.timestamp()

time_deltas = np.random.uniform(0, (max_date - min_date).total_seconds(), num_synthetic_records)
synthetic_timestamps = start_timestamp + time_deltas
synthetic_dates_dt = pd.to_datetime(synthetic_timestamps, unit='s')
synthetic_data['fecha'] = synthetic_dates_dt.strftime('%d/%m/%Y %H:%M:%S')

# Generar las columnas categóricas sintéticas
for col in df.columns:
    if col not in ['fecha', 'fecha_dt']:
        value_counts = df[col].value_counts(normalize=True)
        values = value_counts.index.tolist()
        probabilities = value_counts.values.tolist()
        synthetic_data[col] = np.random.choice(values, size=num_synthetic_records, p=probabilities)

df_synthetic = pd.DataFrame(synthetic_data)

# Mostrar las primeras filas del DataFrame sintético
display(df_synthetic.head())
# Out:
#                  fecha alojamiento       HPAs      HLimp      HWifi  \
# 0  13/08/2025 00:33:08    Hotel 2*  Excelente  Muy Bueno  Excelente
# 1  24/07/2025 23:35:02    Hotel 3*  Excelente  Muy Bueno  Excelente
# 2  17/07/2025 06:13:35    Hotel 1*  Excelente  Excelente  Excelente
# 3  15/06/2025 13:58:39    Hotel 3*  Muy Bueno      Bueno  Muy Bueno
# 4  31/08/2025 09:17:21    Hotel 2*  Muy Bueno  Excelente  Muy Bueno
#
#      HGastro    HEntret HSeguridad       HPyS         H$
# 0  Excelente  Muy Bueno  Muy Bueno  Excelente  Muy Bueno
# 1  Muy Bueno      Bueno  Excelente  Muy Bueno      Bueno
# 2  Excelente      Bueno  Muy Bueno  Excelente  Muy Bueno
# 3  Muy Bueno  Muy Bueno  Excelente  Excelente      Bueno
# 4  Muy Bueno      Bueno  Muy Bueno  Excelente  Muy Bueno

# %% [markdown]
# Hemos creado un DataFrame sintético (`df_synthetic`) con 1000 registros, intentando replicar la distribución de las columnas del DataFrame original. Puedes usar `df_synthetic.info()` y `df_synthetic.value_counts(normalize=True)` para comparar las distribuciones con el DataFrame original si lo deseas.

# %%
df_synthetic.to_csv('df_satHotel.csv', index=False)
print("DataFrame sintético guardado como 'df_satHotel.csv'")
# Out:
# DataFrame sintético guardado como 'df_satHotel.csv'
