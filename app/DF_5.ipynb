# %%
import pandas as pd

df = pd.read_csv('/content/df_5.csv')
display(df.head())
# Out:
#                 fecha      edad      GLimp  GAtencion      GAloj    GGastro  \
# 0   21/7/2025 8:56:40   50 a 64  Muy Buena  Excelente      Buena  Muy Buena
# 1   21/7/2025 9:02:14   30 a 49  Muy Buena  Muy Buena  Muy Buena  Muy Buena
# 2  21/7/2025 18:09:53   50 a 64  Muy Buena  Muy Buena  Muy Buena  Muy Buena
# 3  21/7/2025 18:17:08   50 a 64      Buena  Muy Buena      Buena  Muy Buena
# 4  21/7/2025 19:11:54  65 o más       Malo  Muy Buena  Muy Buena  Muy Buena
#
#       GEntre    GEspArt  GEspDepor
# 0      Buena  Excelente  Muy Buena
# 1  Muy Buena  Muy Buena  Muy Buena
# 2  Muy Buena  Muy Buena  Muy Buena
# 3      Buena      Buena      Buena
# 4       Malo       Malo    Regular

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   fecha      27 non-null     object
#  1   edad       27 non-null     object
#  2   GLimp      27 non-null     object
#  3   GAtencion  27 non-null     object
#  4   GAloj      27 non-null     object
#  5   GGastro    27 non-null     object
#  6   GEntre     27 non-null     object
#  7   GEspArt    27 non-null     object
#  8   GEspDepor  27 non-null     object
# dtypes: object(9)
# memory usage: 2.0+ KB
# None

# %%
for col in df.columns:
    if col != 'fecha': # Assuming 'fecha' is the date column
        print(f"\nDistribución de la columna '{col}':")
        print(df[col].value_counts(normalize=True))
# Out:
# Distribución de la columna 'edad':
# edad
# 50 a 64     0.370370
# 30 a 49     0.333333
# 65 o más    0.148148
# 18 a 29     0.148148
# Name: proportion, dtype: float64
#
# Distribución de la columna 'GLimp':
# GLimp
# Muy Buena    0.444444
# Excelente    0.333333
# Buena        0.148148
# Malo         0.037037
# Regular      0.037037
# Name: proportion, dtype: float64
#
# Distribución de la columna 'GAtencion':
# GAtencion
# Muy Buena    0.666667
# Excelente    0.259259
# Buena        0.074074
# Name: proportion, dtype: float64
#
# Distribución de la columna 'GAloj':
# GAloj
# Muy Buena    0.592593
# Excelente    0.222222
# Buena        0.185185
# Name: proportion, dtype: float64
#
# Distribución de la columna 'GGastro':
# GGastro
# Muy Buena    0.666667
# Excelente    0.296296
# Buena        0.037037
# Name: proportion, dtype: float64
#
# Distribución de la columna 'GEntre':
# GEntre
# Excelente    0.407407
# Muy Buena    0.333333
# Buena        0.148148
# Regular      0.074074
# Malo         0.037037
# Name: proportion, dtype: float64
#
# Distribución de la columna 'GEspArt':
# GEspArt
# Muy Buena    0.407407
# Excelente    0.296296
# Buena        0.185185
# Regular      0.074074
# Malo         0.037037
# Name: proportion, dtype: float64
#
# Distribución de la columna 'GEspDepor':
# GEspDepor
# Muy Buena    0.481481
# Excelente    0.259259
# Buena        0.185185
# Regular      0.074074
# Name: proportion, dtype: float64

# %% [markdown]
# Con la información de los tipos de datos y las distribuciones de las columnas categóricas, ahora puedo generar el DataFrame sintético. La columna `fecha` parece ser un objeto (string) que contiene fecha y hora. Para replicarla, primero la convertiré a tipo `datetime` para obtener el rango y luego generaré fechas aleatorias dentro de ese rango, manteniendo el formato original.

# %%
import numpy as np

# Convertir 'fecha' a datetime para obtener rango
df['fecha_dt'] = pd.to_datetime(df['fecha'], format='%d/%m/%Y %H:%M:%S')

min_date = df['fecha_dt'].min()
max_date = df['fecha_dt'].max()

# Número de registros para el DataFrame sintético
num_synthetic_records = 1000

synthetic_data = {}

# Generar la columna 'fecha' sintética
start_timestamp = min_date.timestamp()
end_timestamp = max_date.timestamp()

time_deltas = np.random.uniform(0, (max_date - min_date).total_seconds(), num_synthetic_records)
synthetic_timestamps = start_timestamp + time_deltas
synthetic_dates_dt = pd.to_datetime(synthetic_timestamps, unit='s')
synthetic_data['fecha'] = synthetic_dates_dt.strftime('%d/%m/%Y %H:%M:%S')

# Generar las columnas categóricas sintéticas
for col in df.columns:
    if col not in ['fecha', 'fecha_dt']:
        value_counts = df[col].value_counts(normalize=True)
        values = value_counts.index.tolist()
        probabilities = value_counts.values.tolist()
        synthetic_data[col] = np.random.choice(values, size=num_synthetic_records, p=probabilities)

df_synthetic = pd.DataFrame(synthetic_data)

# Mostrar las primeras filas del DataFrame sintético
display(df_synthetic.head())
# Out:
#                  fecha      edad      GLimp  GAtencion      GAloj    GGastro  \
# 0  30/07/2025 22:16:05   18 a 29  Muy Buena  Muy Buena  Muy Buena  Excelente
# 1  05/07/2025 03:53:27  65 o más  Muy Buena  Muy Buena  Muy Buena  Muy Buena
# 2  08/09/2025 20:54:51   50 a 64  Muy Buena  Muy Buena  Muy Buena  Excelente
# 3  21/10/2025 16:38:41   50 a 64  Muy Buena  Muy Buena  Muy Buena  Excelente
# 4  28/09/2025 14:08:05  65 o más  Muy Buena      Buena  Muy Buena      Buena
#
#       GEntre    GEspArt  GEspDepor
# 0      Buena       Malo  Excelente
# 1  Excelente  Muy Buena      Buena
# 2      Buena  Muy Buena  Muy Buena
# 3  Excelente  Muy Buena  Excelente
# 4      Buena  Muy Buena  Muy Buena

# %%
df_synthetic.shape
# Out:
# (1000, 9)

# %% [markdown]
# Hemos creado un DataFrame sintético (`df_synthetic`) con 1000 registros, intentando replicar la distribución de las columnas del DataFrame original. Puedes usar `df_synthetic.info()` y `df_synthetic.value_counts(normalize=True)` para comparar las distribuciones con el DataFrame original si lo deseas.

# %%
df_synthetic.to_csv('df_satGral.csv', index=False)
print("DataFrame sintético guardado como 'df_satGral.csv'")
# Out:
# DataFrame sintético guardado como 'df_satGral.csv'
